# %%
import argparse
#from tot.methods.bfs import solve
#from tot.tasks.game24 import Game24Task
import sys
import os

# Add the directory containing the module to the system path
module_path = os.path.join("C:", "Users", "sheld", "Documents", "GitHub", "tree-of-thought-llm", "src")
if module_path not in sys.path:
    sys.path.append(module_path)

from src.tot.methods.bfs import solve,naive_solve, bfs_checker
from src.tot.tasks.game24 import Game24Task, checker
# Out:
# llm ready

# %%
checker()
bfs_checker()
# Out:
# checker confirmed
# bfs ready

# %%
args = argparse.Namespace(backend='llama3', 
                          temperature=0.7, task='game24', naive_run=True, prompt_sample='cot', n_generate_sample=1,)
task = Game24Task()

# %%
ys, infos = naive_solve(args, task, 900)
print(ys)
# Out:
# functools.partial(<function gpt at 0x000001EDCA027B00>, model='llama3', temperature=0.7)
# output generating get_samples
# Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.
# Input: 4 4 6 8
# Steps:
# 4 + 8 = 12 (left: 4 6 12)
# 6 - 4 = 2 (left: 2 12)
# 2 * 12 = 24 (left: 24)
# Answer: (6 - 4) * (4 + 8) = 24
# Input: 2 9 10 12
# Steps:
# 12 * 2 = 24 (left: 9 10 24)
# 10 - 9 = 1 (left: 1 24)
# 24 * 1 = 24 (left: 24)
# Answer: (12 * 2) * (10 - 9) = 24
# Input: 4 9 10 13
# Steps:
# 13 - 10 = 3 (left: 3 4 9)
# 9 - 3 = 6 (left: 4 6)
# 4 * 6 = 24 (left: 24)
# Answer: 4 * (9 - (13 - 10)) = 24
# Input: 1 4 8 8
# Steps:
# 8 / 4 = 2 (left: 1 2 8)
# 1 + 2 = 3 (left: 3 8)
# 3 * 8 = 24 (left: 24)
# Answer: (1 + 8 / 4) * 8 = 24
# Input: 5 5 5 9
# Steps:
# 5 + 5 = 10 (left: 5 9 10)
# 10 + 5 = 15 (left: 9 15)
# 15 + 9 = 24 (left: 24)
# Answer: ((5 + 5) + 5) + 9 = 24
# Input: 4 5 6 10
#
# 1
# 1 [{'role': 'user', 'content': 'Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.\nInput: 4 4 6 8\nSteps:\n4 + 8 = 12 (left: 4 6 12)\n6 - 4 = 2 (left: 2 12)\n2 * 12 = 24 (left: 24)\nAnswer: (6 - 4) * (4 + 8) = 24\nInput: 2 9 10 12\nSteps:\n12 * 2 = 24 (left: 9 10 24)\n10 - 9 = 1 (left: 1 24)\n24 * 1 = 24 (left: 24)\nAnswer: (12 * 2) * (10 - 9) = 24\nInput: 4 9 10 13\nSteps:\n13 - 10 = 3 (left: 3 4 9)\n9 - 3 = 6 (left: 4 6)\n4 * 6 = 24 (left: 24)\nAnswer: 4 * (9 - (13 - 10)) = 24\nInput: 1 4 8 8\nSteps:\n8 / 4 = 2 (left: 1 2 8)\n1 + 2 = 3 (left: 3 8)\n3 * 8 = 24 (left: 24)\nAnswer: (1 + 8 / 4) * 8 = 24\nInput: 5 5 5 9\nSteps:\n5 + 5 = 10 (left: 5 9 10)\n10 + 5 = 15 (left: 9 15)\n15 + 9 = 24 (left: 24)\nAnswer: ((5 + 5) + 5) + 9 = 24\nInput: 4 5 6 10\n'}]
# A fun challenge!
#
# Let's follow the rules and see what we can come up with:
#
# Steps:
# 10 - 6 = 4 (left: 4, 5)
# 4 * 5 = 20 (left: 20, 4)
# 20 + 4 = 24 (left: 24)
#
# Answer: (10 - 6) * (4 * 5) + 4 = 24
# output generated
# ["A fun challenge!\n\nLet's follow the rules and see what we can come up with:\n\nSteps:\n10 - 6 = 4 (left: 4, 5)\n4 * 5 = 20 (left: 20, 4)\n20 + 4 = 24 (left: 24)\n\nAnswer: (10 - 6) * (4 * 5) + 4 = 24"]

# %%
ys, infos = naive_solve(args, task, 901)
print(ys)
# Out:
# functools.partial(<function gpt at 0x000001EDCA027B00>, model='llama3', temperature=0.7)
# output generating get_samples
# Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.
# Input: 4 4 6 8
# Steps:
# 4 + 8 = 12 (left: 4 6 12)
# 6 - 4 = 2 (left: 2 12)
# 2 * 12 = 24 (left: 24)
# Answer: (6 - 4) * (4 + 8) = 24
# Input: 2 9 10 12
# Steps:
# 12 * 2 = 24 (left: 9 10 24)
# 10 - 9 = 1 (left: 1 24)
# 24 * 1 = 24 (left: 24)
# Answer: (12 * 2) * (10 - 9) = 24
# Input: 4 9 10 13
# Steps:
# 13 - 10 = 3 (left: 3 4 9)
# 9 - 3 = 6 (left: 4 6)
# 4 * 6 = 24 (left: 24)
# Answer: 4 * (9 - (13 - 10)) = 24
# Input: 1 4 8 8
# Steps:
# 8 / 4 = 2 (left: 1 2 8)
# 1 + 2 = 3 (left: 3 8)
# 3 * 8 = 24 (left: 24)
# Answer: (1 + 8 / 4) * 8 = 24
# Input: 5 5 5 9
# Steps:
# 5 + 5 = 10 (left: 5 9 10)
# 10 + 5 = 15 (left: 9 15)
# 15 + 9 = 24 (left: 24)
# Answer: ((5 + 5) + 5) + 9 = 24
# Input: 1 2 4 7
#
# 1
# 1 [{'role': 'user', 'content': 'Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.\nInput: 4 4 6 8\nSteps:\n4 + 8 = 12 (left: 4 6 12)\n6 - 4 = 2 (left: 2 12)\n2 * 12 = 24 (left: 24)\nAnswer: (6 - 4) * (4 + 8) = 24\nInput: 2 9 10 12\nSteps:\n12 * 2 = 24 (left: 9 10 24)\n10 - 9 = 1 (left: 1 24)\n24 * 1 = 24 (left: 24)\nAnswer: (12 * 2) * (10 - 9) = 24\nInput: 4 9 10 13\nSteps:\n13 - 10 = 3 (left: 3 4 9)\n9 - 3 = 6 (left: 4 6)\n4 * 6 = 24 (left: 24)\nAnswer: 4 * (9 - (13 - 10)) = 24\nInput: 1 4 8 8\nSteps:\n8 / 4 = 2 (left: 1 2 8)\n1 + 2 = 3 (left: 3 8)\n3 * 8 = 24 (left: 24)\nAnswer: (1 + 8 / 4) * 8 = 24\nInput: 5 5 5 9\nSteps:\n5 + 5 = 10 (left: 5 9 10)\n10 + 5 = 15 (left: 9 15)\n15 + 9 = 24 (left: 24)\nAnswer: ((5 + 5) + 5) + 9 = 24\nInput: 1 2 4 7\n'}]
# A fun challenge!
#
# Let's try to obtain 24 using the given numbers (1, 2, 4, and 7).
#
# Steps:
# 1. 7 - 2 = 5 (left: 1, 4, 5)
# 2. 5 * 4 = 20 (left: 1, 20)
# 3. 20 + 1 = 21 (left: 21)
# 4. 21 + 4 = 25 (oops, too high!)
# 5. 7 - 1 = 6 (left: 2, 6)
# 6. 6 * 4 = 24 (voilà!)
#
# Answer: (7 - 2) * 4 + (7 - 1) = 24
#
# Did I get it right?
# output generated
# ["A fun challenge!\n\nLet's try to obtain 24 using the given numbers (1, 2, 4, and 7).\n\nSteps:\n1. 7 - 2 = 5 (left: 1, 4, 5)\n2. 5 * 4 = 20 (left: 1, 20)\n3. 20 + 1 = 21 (left: 21)\n4. 21 + 4 = 25 (oops, too high!)\n5. 7 - 1 = 6 (left: 2, 6)\n6. 6 * 4 = 24 (voilà!)\n\nAnswer: (7 - 2) * 4 + (7 - 1) = 24\n\nDid I get it right?"]

# %%
ys, infos = naive_solve(args, task, 902)
print(ys)
# Out:
# functools.partial(<function gpt at 0x000001EDCA027B00>, model='llama3', temperature=0.7)
# output generating get_samples
# Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.
# Input: 4 4 6 8
# Steps:
# 4 + 8 = 12 (left: 4 6 12)
# 6 - 4 = 2 (left: 2 12)
# 2 * 12 = 24 (left: 24)
# Answer: (6 - 4) * (4 + 8) = 24
# Input: 2 9 10 12
# Steps:
# 12 * 2 = 24 (left: 9 10 24)
# 10 - 9 = 1 (left: 1 24)
# 24 * 1 = 24 (left: 24)
# Answer: (12 * 2) * (10 - 9) = 24
# Input: 4 9 10 13
# Steps:
# 13 - 10 = 3 (left: 3 4 9)
# 9 - 3 = 6 (left: 4 6)
# 4 * 6 = 24 (left: 24)
# Answer: 4 * (9 - (13 - 10)) = 24
# Input: 1 4 8 8
# Steps:
# 8 / 4 = 2 (left: 1 2 8)
# 1 + 2 = 3 (left: 3 8)
# 3 * 8 = 24 (left: 24)
# Answer: (1 + 8 / 4) * 8 = 24
# Input: 5 5 5 9
# Steps:
# 5 + 5 = 10 (left: 5 9 10)
# 10 + 5 = 15 (left: 9 15)
# 15 + 9 = 24 (left: 24)
# Answer: ((5 + 5) + 5) + 9 = 24
# Input: 2 5 8 11
#
# 1
# 1 [{'role': 'user', 'content': 'Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.\nInput: 4 4 6 8\nSteps:\n4 + 8 = 12 (left: 4 6 12)\n6 - 4 = 2 (left: 2 12)\n2 * 12 = 24 (left: 24)\nAnswer: (6 - 4) * (4 + 8) = 24\nInput: 2 9 10 12\nSteps:\n12 * 2 = 24 (left: 9 10 24)\n10 - 9 = 1 (left: 1 24)\n24 * 1 = 24 (left: 24)\nAnswer: (12 * 2) * (10 - 9) = 24\nInput: 4 9 10 13\nSteps:\n13 - 10 = 3 (left: 3 4 9)\n9 - 3 = 6 (left: 4 6)\n4 * 6 = 24 (left: 24)\nAnswer: 4 * (9 - (13 - 10)) = 24\nInput: 1 4 8 8\nSteps:\n8 / 4 = 2 (left: 1 2 8)\n1 + 2 = 3 (left: 3 8)\n3 * 8 = 24 (left: 24)\nAnswer: (1 + 8 / 4) * 8 = 24\nInput: 5 5 5 9\nSteps:\n5 + 5 = 10 (left: 5 9 10)\n10 + 5 = 15 (left: 9 15)\n15 + 9 = 24 (left: 24)\nAnswer: ((5 + 5) + 5) + 9 = 24\nInput: 2 5 8 11\n'}]
# A fun puzzle!
#
# Let's follow the steps:
#
# 1. 11 - 5 = 6 (left: 2, 5, 6, 8)
# 2. 8 + 2 = 10 (left: 5, 6, 10)
# 3. 10 * 6 = 60 (oops, not 24!)
# 4. Since we didn't reach 24, let's try another combination:
#    - 11 - 2 = 9 (left: 5, 8, 9)
#    - 8 + 5 = 13 (not 24 either!)
#    - Hmm, maybe we can combine the last two steps?
#    - 11 - 8 = 3 (left: 2, 5, 3)
#    - 5 * 3 = 15 (still not 24...)
#    - Wait a minute...
#    - 9 + 2 = 11 (not 24 either!)
#    - But what if we combine the last two steps again?
#    - 9 + 5 = 14 (close, but still not 24!)
#    - Ah ha!
#    - 14 + 2 = 16 (getting closer...)
#    - 16 + 8 = 24 (yay, finally!)
#
# So, the correct sequence of operations is:
#
# (11 - 2) + (9 + 5) + 8 = 24
#
# Answer: (11 - 2) + (9 + 5) + 8 = 24
# output generated
# ["A fun puzzle!\n\nLet's follow the steps:\n\n1. 11 - 5 = 6 (left: 2, 5, 6, 8)\n2. 8 + 2 = 10 (left: 5, 6, 10)\n3. 10 * 6 = 60 (oops, not 24!)\n4. Since we didn't reach 24, let's try another combination:\n   - 11 - 2 = 9 (left: 5, 8, 9)\n   - 8 + 5 = 13 (not 24 either!)\n   - Hmm, maybe we can combine the last two steps?\n   - 11 - 8 = 3 (left: 2, 5, 3)\n   - 5 * 3 = 15 (still not 24...)\n   - Wait a minute...\n   - 9 + 2 = 11 (not 24 either!)\n   - But what if we combine the last two steps again?\n   - 9 + 5 = 14 (close, but still not 24!)\n   - Ah ha!\n   - 14 + 2 = 16 (getting closer...)\n   - 16 + 8 = 24 (yay, finally!)\n\nSo, the correct sequence of operations is:\n\n(11 - 2) + (9 + 5) + 8 = 24\n\nAnswer: (11 - 2) + (9 + 5) + 8 = 24"]

# %%
ys, infos = naive_solve(args, task, 903)
print(ys)
# Out:
# functools.partial(<function gpt at 0x000001EDCA027B00>, model='llama3', temperature=0.7)
# output generating get_samples
# Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.
# Input: 4 4 6 8
# Steps:
# 4 + 8 = 12 (left: 4 6 12)
# 6 - 4 = 2 (left: 2 12)
# 2 * 12 = 24 (left: 24)
# Answer: (6 - 4) * (4 + 8) = 24
# Input: 2 9 10 12
# Steps:
# 12 * 2 = 24 (left: 9 10 24)
# 10 - 9 = 1 (left: 1 24)
# 24 * 1 = 24 (left: 24)
# Answer: (12 * 2) * (10 - 9) = 24
# Input: 4 9 10 13
# Steps:
# 13 - 10 = 3 (left: 3 4 9)
# 9 - 3 = 6 (left: 4 6)
# 4 * 6 = 24 (left: 24)
# Answer: 4 * (9 - (13 - 10)) = 24
# Input: 1 4 8 8
# Steps:
# 8 / 4 = 2 (left: 1 2 8)
# 1 + 2 = 3 (left: 3 8)
# 3 * 8 = 24 (left: 24)
# Answer: (1 + 8 / 4) * 8 = 24
# Input: 5 5 5 9
# Steps:
# 5 + 5 = 10 (left: 5 9 10)
# 10 + 5 = 15 (left: 9 15)
# 15 + 9 = 24 (left: 24)
# Answer: ((5 + 5) + 5) + 9 = 24
# Input: 3 4 4 13
#
# 1
# 1 [{'role': 'user', 'content': 'Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.\nInput: 4 4 6 8\nSteps:\n4 + 8 = 12 (left: 4 6 12)\n6 - 4 = 2 (left: 2 12)\n2 * 12 = 24 (left: 24)\nAnswer: (6 - 4) * (4 + 8) = 24\nInput: 2 9 10 12\nSteps:\n12 * 2 = 24 (left: 9 10 24)\n10 - 9 = 1 (left: 1 24)\n24 * 1 = 24 (left: 24)\nAnswer: (12 * 2) * (10 - 9) = 24\nInput: 4 9 10 13\nSteps:\n13 - 10 = 3 (left: 3 4 9)\n9 - 3 = 6 (left: 4 6)\n4 * 6 = 24 (left: 24)\nAnswer: 4 * (9 - (13 - 10)) = 24\nInput: 1 4 8 8\nSteps:\n8 / 4 = 2 (left: 1 2 8)\n1 + 2 = 3 (left: 3 8)\n3 * 8 = 24 (left: 24)\nAnswer: (1 + 8 / 4) * 8 = 24\nInput: 5 5 5 9\nSteps:\n5 + 5 = 10 (left: 5 9 10)\n10 + 5 = 15 (left: 9 15)\n15 + 9 = 24 (left: 24)\nAnswer: ((5 + 5) + 5) + 9 = 24\nInput: 3 4 4 13\n'}]
# Let's follow the steps to obtain 24:
#
# 1. 13 - 4 = 9 (left: 3 4 9)
# 2. 9 + 4 = 13 (left: 3 13)
# 3. 13 * 3 = 39 (not equal to 24, so we need to backtrack)
#
# Let's try a different combination:
#
# 1. 13 - 4 = 9 (left: 3 4 9)
# 2. 4 + 4 = 8 (left: 3 8 9)
# 3. 9 - 8 = 1 (left: 1 3)
# 4. 1 * 3 * 8 = 24 (left: 24)
#
# So, the answer is:
#
# (13 - 4) + (4 + 4) * (9 - 8) = 24
# output generated
# ["Let's follow the steps to obtain 24:\n\n1. 13 - 4 = 9 (left: 3 4 9)\n2. 9 + 4 = 13 (left: 3 13) \n3. 13 * 3 = 39 (not equal to 24, so we need to backtrack)\n\nLet's try a different combination:\n\n1. 13 - 4 = 9 (left: 3 4 9)\n2. 4 + 4 = 8 (left: 3 8 9)\n3. 9 - 8 = 1 (left: 1 3) \n4. 1 * 3 * 8 = 24 (left: 24)\n\nSo, the answer is:\n\n(13 - 4) + (4 + 4) * (9 - 8) = 24"]

# %%
ys, infos = naive_solve(args, task, 904)
print(ys)
# Out:
# functools.partial(<function gpt at 0x000001EDCA027B00>, model='llama3', temperature=0.7)
# output generating get_samples
# Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.
# Input: 4 4 6 8
# Steps:
# 4 + 8 = 12 (left: 4 6 12)
# 6 - 4 = 2 (left: 2 12)
# 2 * 12 = 24 (left: 24)
# Answer: (6 - 4) * (4 + 8) = 24
# Input: 2 9 10 12
# Steps:
# 12 * 2 = 24 (left: 9 10 24)
# 10 - 9 = 1 (left: 1 24)
# 24 * 1 = 24 (left: 24)
# Answer: (12 * 2) * (10 - 9) = 24
# Input: 4 9 10 13
# Steps:
# 13 - 10 = 3 (left: 3 4 9)
# 9 - 3 = 6 (left: 4 6)
# 4 * 6 = 24 (left: 24)
# Answer: 4 * (9 - (13 - 10)) = 24
# Input: 1 4 8 8
# Steps:
# 8 / 4 = 2 (left: 1 2 8)
# 1 + 2 = 3 (left: 3 8)
# 3 * 8 = 24 (left: 24)
# Answer: (1 + 8 / 4) * 8 = 24
# Input: 5 5 5 9
# Steps:
# 5 + 5 = 10 (left: 5 9 10)
# 10 + 5 = 15 (left: 9 15)
# 15 + 9 = 24 (left: 24)
# Answer: ((5 + 5) + 5) + 9 = 24
# Input: 6 7 8 9
#
# 1
# 1 [{'role': 'user', 'content': 'Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.\nInput: 4 4 6 8\nSteps:\n4 + 8 = 12 (left: 4 6 12)\n6 - 4 = 2 (left: 2 12)\n2 * 12 = 24 (left: 24)\nAnswer: (6 - 4) * (4 + 8) = 24\nInput: 2 9 10 12\nSteps:\n12 * 2 = 24 (left: 9 10 24)\n10 - 9 = 1 (left: 1 24)\n24 * 1 = 24 (left: 24)\nAnswer: (12 * 2) * (10 - 9) = 24\nInput: 4 9 10 13\nSteps:\n13 - 10 = 3 (left: 3 4 9)\n9 - 3 = 6 (left: 4 6)\n4 * 6 = 24 (left: 24)\nAnswer: 4 * (9 - (13 - 10)) = 24\nInput: 1 4 8 8\nSteps:\n8 / 4 = 2 (left: 1 2 8)\n1 + 2 = 3 (left: 3 8)\n3 * 8 = 24 (left: 24)\nAnswer: (1 + 8 / 4) * 8 = 24\nInput: 5 5 5 9\nSteps:\n5 + 5 = 10 (left: 5 9 10)\n10 + 5 = 15 (left: 9 15)\n15 + 9 = 24 (left: 24)\nAnswer: ((5 + 5) + 5) + 9 = 24\nInput: 6 7 8 9\n'}]
# Another challenge!
#
# Let's go through the steps:
#
# 1. 9 + 8 = 17 (left: 6, 7, 17)
# 2. 17 - 6 = 11 (left: 7, 11)
# 3. 11 * 7 = 77 (not enough, so we backtrack)
# 4. 8 * 7 = 56 (not enough, so we backtrack again)
# 5. 9 - 7 = 2 (left: 6, 2, 9)
# 6. 9 + 2 = 11 (left: 6, 11)
# 7. 11 * 6 = 66 (not enough, so we backtrack once more)
# 8. 9 - 6 = 3 (left: 3, 3, 9)
# 9. 9 / 3 = 3 (left: 1, 2, 3)
# 10. 3 + 1 = 4 (left: 2, 4)
# 11. 4 * 2 = 8 (not enough, so we backtrack again)
# 12. 2 * 3 = 6 (left: 1, 6)
# 13. 1 + 6 = 7 (not enough, so we backtrack once more)
# 14. 9 - 3 = 6 (left: 6, 9)
# 15. 6 * 9 = 54 (not enough, so we give up.
#
# It seems that there is no way to obtain 24 using the given numbers and basic arithmetic operations (+, -, *, /).
# output generated
# ["Another challenge!\n\nLet's go through the steps:\n\n1. 9 + 8 = 17 (left: 6, 7, 17)\n2. 17 - 6 = 11 (left: 7, 11)\n3. 11 * 7 = 77 (not enough, so we backtrack)\n4. 8 * 7 = 56 (not enough, so we backtrack again)\n5. 9 - 7 = 2 (left: 6, 2, 9)\n6. 9 + 2 = 11 (left: 6, 11)\n7. 11 * 6 = 66 (not enough, so we backtrack once more)\n8. 9 - 6 = 3 (left: 3, 3, 9)\n9. 9 / 3 = 3 (left: 1, 2, 3)\n10. 3 + 1 = 4 (left: 2, 4)\n11. 4 * 2 = 8 (not enough, so we backtrack again)\n12. 2 * 3 = 6 (left: 1, 6)\n13. 1 + 6 = 7 (not enough, so we backtrack once more)\n14. 9 - 3 = 6 (left: 6, 9)\n15. 6 * 9 = 54 (not enough, so we give up.\n\nIt seems that there is no way to obtain 24 using the given numbers and basic arithmetic operations (+, -, *, /)."]

# %%
ys, infos = naive_solve(args, task, 905)
print(ys)
# Out:
# functools.partial(<function gpt at 0x000001EDCA027B00>, model='llama3', temperature=0.7)
# output generating get_samples
# Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.
# Input: 4 4 6 8
# Steps:
# 4 + 8 = 12 (left: 4 6 12)
# 6 - 4 = 2 (left: 2 12)
# 2 * 12 = 24 (left: 24)
# Answer: (6 - 4) * (4 + 8) = 24
# Input: 2 9 10 12
# Steps:
# 12 * 2 = 24 (left: 9 10 24)
# 10 - 9 = 1 (left: 1 24)
# 24 * 1 = 24 (left: 24)
# Answer: (12 * 2) * (10 - 9) = 24
# Input: 4 9 10 13
# Steps:
# 13 - 10 = 3 (left: 3 4 9)
# 9 - 3 = 6 (left: 4 6)
# 4 * 6 = 24 (left: 24)
# Answer: 4 * (9 - (13 - 10)) = 24
# Input: 1 4 8 8
# Steps:
# 8 / 4 = 2 (left: 1 2 8)
# 1 + 2 = 3 (left: 3 8)
# 3 * 8 = 24 (left: 24)
# Answer: (1 + 8 / 4) * 8 = 24
# Input: 5 5 5 9
# Steps:
# 5 + 5 = 10 (left: 5 9 10)
# 10 + 5 = 15 (left: 9 15)
# 15 + 9 = 24 (left: 24)
# Answer: ((5 + 5) + 5) + 9 = 24
# Input: 1 11 11 13
#
# 1
# 1 [{'role': 'user', 'content': 'Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.\nInput: 4 4 6 8\nSteps:\n4 + 8 = 12 (left: 4 6 12)\n6 - 4 = 2 (left: 2 12)\n2 * 12 = 24 (left: 24)\nAnswer: (6 - 4) * (4 + 8) = 24\nInput: 2 9 10 12\nSteps:\n12 * 2 = 24 (left: 9 10 24)\n10 - 9 = 1 (left: 1 24)\n24 * 1 = 24 (left: 24)\nAnswer: (12 * 2) * (10 - 9) = 24\nInput: 4 9 10 13\nSteps:\n13 - 10 = 3 (left: 3 4 9)\n9 - 3 = 6 (left: 4 6)\n4 * 6 = 24 (left: 24)\nAnswer: 4 * (9 - (13 - 10)) = 24\nInput: 1 4 8 8\nSteps:\n8 / 4 = 2 (left: 1 2 8)\n1 + 2 = 3 (left: 3 8)\n3 * 8 = 24 (left: 24)\nAnswer: (1 + 8 / 4) * 8 = 24\nInput: 5 5 5 9\nSteps:\n5 + 5 = 10 (left: 5 9 10)\n10 + 5 = 15 (left: 9 15)\n15 + 9 = 24 (left: 24)\nAnswer: ((5 + 5) + 5) + 9 = 24\nInput: 1 11 11 13\n'}]
# Let's go through the steps to obtain 24 using basic arithmetic operations (+, -, *, /).
#
# Steps:
# 11 - 1 = 10 (left: 1 11 13)
# 13 - 11 = 2 (left: 1 2 10)
# 2 * 10 = 20 (left: 1 20)
# 20 + 4 = 24 (left: 24)
#
# Answer: (11 - 1) * (13 - 11) + 4 = 24
# output generated
# ["Let's go through the steps to obtain 24 using basic arithmetic operations (+, -, *, /).\n\nSteps:\n11 - 1 = 10 (left: 1 11 13)\n13 - 11 = 2 (left: 1 2 10)\n2 * 10 = 20 (left: 1 20)\n20 + 4 = 24 (left: 24)\n\nAnswer: (11 - 1) * (13 - 11) + 4 = 24"]

# %%
ys, infos = naive_solve(args, task, 906)
print(ys)
# Out:
# functools.partial(<function gpt at 0x000001EDCA027B00>, model='llama3', temperature=0.7)
# output generating get_samples
# Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.
# Input: 4 4 6 8
# Steps:
# 4 + 8 = 12 (left: 4 6 12)
# 6 - 4 = 2 (left: 2 12)
# 2 * 12 = 24 (left: 24)
# Answer: (6 - 4) * (4 + 8) = 24
# Input: 2 9 10 12
# Steps:
# 12 * 2 = 24 (left: 9 10 24)
# 10 - 9 = 1 (left: 1 24)
# 24 * 1 = 24 (left: 24)
# Answer: (12 * 2) * (10 - 9) = 24
# Input: 4 9 10 13
# Steps:
# 13 - 10 = 3 (left: 3 4 9)
# 9 - 3 = 6 (left: 4 6)
# 4 * 6 = 24 (left: 24)
# Answer: 4 * (9 - (13 - 10)) = 24
# Input: 1 4 8 8
# Steps:
# 8 / 4 = 2 (left: 1 2 8)
# 1 + 2 = 3 (left: 3 8)
# 3 * 8 = 24 (left: 24)
# Answer: (1 + 8 / 4) * 8 = 24
# Input: 5 5 5 9
# Steps:
# 5 + 5 = 10 (left: 5 9 10)
# 10 + 5 = 15 (left: 9 15)
# 15 + 9 = 24 (left: 24)
# Answer: ((5 + 5) + 5) + 9 = 24
# Input: 1 8 10 11
#
# 1
# 1 [{'role': 'user', 'content': 'Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.\nInput: 4 4 6 8\nSteps:\n4 + 8 = 12 (left: 4 6 12)\n6 - 4 = 2 (left: 2 12)\n2 * 12 = 24 (left: 24)\nAnswer: (6 - 4) * (4 + 8) = 24\nInput: 2 9 10 12\nSteps:\n12 * 2 = 24 (left: 9 10 24)\n10 - 9 = 1 (left: 1 24)\n24 * 1 = 24 (left: 24)\nAnswer: (12 * 2) * (10 - 9) = 24\nInput: 4 9 10 13\nSteps:\n13 - 10 = 3 (left: 3 4 9)\n9 - 3 = 6 (left: 4 6)\n4 * 6 = 24 (left: 24)\nAnswer: 4 * (9 - (13 - 10)) = 24\nInput: 1 4 8 8\nSteps:\n8 / 4 = 2 (left: 1 2 8)\n1 + 2 = 3 (left: 3 8)\n3 * 8 = 24 (left: 24)\nAnswer: (1 + 8 / 4) * 8 = 24\nInput: 5 5 5 9\nSteps:\n5 + 5 = 10 (left: 5 9 10)\n10 + 5 = 15 (left: 9 15)\n15 + 9 = 24 (left: 24)\nAnswer: ((5 + 5) + 5) + 9 = 24\nInput: 1 8 10 11\n'}]
# I'd be happy to help you with that!
#
# Let's follow the steps:
#
# Steps:
# 11 - 8 = 3 (left: 1, 3, 10)
# 10 + 3 = 13 (left: 1, 13)
# 13 + 1 = 14 (left: none)
# Wait, we can't get to 24 with 14. Let's try again!
#
# Steps:
# 11 - 1 = 10 (left: 8, 10)
# 8 * 10 = 80 (left: none)
# Oh no! We went way over 24.
#
# Let me try again:
#
# Steps:
# 10 + 1 = 11 (left: 8, 11)
# 11 - 8 = 3 (left: none)
# Hmm... still not working. Let's think outside the box!
#
# Steps:
# 11 / 1 = 11 (left: 8, 11)
# 8 * 11 = 88 (left: none)
# Whoops! Too high again.
#
# Let me try once more:
#
# Steps:
# 8 + 1 = 9 (left: 10, 9)
# 9 - 1 = 8 (left: 10, 8)
# 10 + 8 = 18 (left: none)
# Uh-oh! Not quite there yet. One more time, please!
#
# Steps:
# 11 / 1 = 11 (left: 8, 11)
# 8 + 1 = 9 (left: 9, 11)
# 9 * 11 = 99 (left: none)
# Oops, still too high!
#
# Let me think... Ah ha! One more time:
#
# Steps:
# 10 - 1 = 9 (left: 8, 9)
# 8 + 9 = 17 (left: none)
# Hmm... almost there. Just one more step:
#
# Steps:
# 11 / 1 = 11 (left: 8, 11)
# 8 * 3 = 24 (left: none)
#
# And that's it! We finally got to 24!
#
# Answer: ((10 - 1) + 8) * (11 / 1) = 24
# output generated
# ["I'd be happy to help you with that!\n\nLet's follow the steps:\n\nSteps:\n11 - 8 = 3 (left: 1, 3, 10)\n10 + 3 = 13 (left: 1, 13)\n13 + 1 = 14 (left: none)\nWait, we can't get to 24 with 14. Let's try again!\n\nSteps:\n11 - 1 = 10 (left: 8, 10)\n8 * 10 = 80 (left: none)\nOh no! We went way over 24.\n\nLet me try again:\n\nSteps:\n10 + 1 = 11 (left: 8, 11)\n11 - 8 = 3 (left: none)\nHmm... still not working. Let's think outside the box!\n\nSteps:\n11 / 1 = 11 (left: 8, 11)\n8 * 11 = 88 (left: none)\nWhoops! Too high again.\n\nLet me try once more:\n\nSteps:\n8 + 1 = 9 (left: 10, 9)\n9 - 1 = 8 (left: 10, 8)\n10 + 8 = 18 (left: none)\nUh-oh! Not quite there yet. One more time, please!\n\nSteps:\n11 / 1 = 11 (left: 8, 11)\n8 + 1 = 9 (left: 9, 11)\n9 * 11 = 99 (left: none)\nOops, still too high!\n\nLet me think... Ah ha! One more time:\n\nSteps:\n10 - 1 = 9 (left: 8, 9)\n8 + 9 = 17 (left: none)\nHmm... almost there. Just one more step:\n\nSteps:\n11 / 1 = 11 (left: 8, 11)\n8 * 3 = 24 (left: none)\n\nAnd that's it! We finally got to 24!\n\nAnswer: ((10 - 1) + 8) * (11 / 1) = 24"]

# %%
ys, infos = naive_solve(args, task, 907)
print(ys)
# Out:
# functools.partial(<function gpt at 0x000001EDCA027B00>, model='llama3', temperature=0.7)
# output generating get_samples
# Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.
# Input: 4 4 6 8
# Steps:
# 4 + 8 = 12 (left: 4 6 12)
# 6 - 4 = 2 (left: 2 12)
# 2 * 12 = 24 (left: 24)
# Answer: (6 - 4) * (4 + 8) = 24
# Input: 2 9 10 12
# Steps:
# 12 * 2 = 24 (left: 9 10 24)
# 10 - 9 = 1 (left: 1 24)
# 24 * 1 = 24 (left: 24)
# Answer: (12 * 2) * (10 - 9) = 24
# Input: 4 9 10 13
# Steps:
# 13 - 10 = 3 (left: 3 4 9)
# 9 - 3 = 6 (left: 4 6)
# 4 * 6 = 24 (left: 24)
# Answer: 4 * (9 - (13 - 10)) = 24
# Input: 1 4 8 8
# Steps:
# 8 / 4 = 2 (left: 1 2 8)
# 1 + 2 = 3 (left: 3 8)
# 3 * 8 = 24 (left: 24)
# Answer: (1 + 8 / 4) * 8 = 24
# Input: 5 5 5 9
# Steps:
# 5 + 5 = 10 (left: 5 9 10)
# 10 + 5 = 15 (left: 9 15)
# 15 + 9 = 24 (left: 24)
# Answer: ((5 + 5) + 5) + 9 = 24
# Input: 2 3 6 9
#
# 1
# 1 [{'role': 'user', 'content': 'Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.\nInput: 4 4 6 8\nSteps:\n4 + 8 = 12 (left: 4 6 12)\n6 - 4 = 2 (left: 2 12)\n2 * 12 = 24 (left: 24)\nAnswer: (6 - 4) * (4 + 8) = 24\nInput: 2 9 10 12\nSteps:\n12 * 2 = 24 (left: 9 10 24)\n10 - 9 = 1 (left: 1 24)\n24 * 1 = 24 (left: 24)\nAnswer: (12 * 2) * (10 - 9) = 24\nInput: 4 9 10 13\nSteps:\n13 - 10 = 3 (left: 3 4 9)\n9 - 3 = 6 (left: 4 6)\n4 * 6 = 24 (left: 24)\nAnswer: 4 * (9 - (13 - 10)) = 24\nInput: 1 4 8 8\nSteps:\n8 / 4 = 2 (left: 1 2 8)\n1 + 2 = 3 (left: 3 8)\n3 * 8 = 24 (left: 24)\nAnswer: (1 + 8 / 4) * 8 = 24\nInput: 5 5 5 9\nSteps:\n5 + 5 = 10 (left: 5 9 10)\n10 + 5 = 15 (left: 9 15)\n15 + 9 = 24 (left: 24)\nAnswer: ((5 + 5) + 5) + 9 = 24\nInput: 2 3 6 9\n'}]
# A fun challenge!
#
# Let's go through the steps:
#
# 1. 9 + 6 = 15 (left: 2, 3, 15)
# 2. 15 - 2 = 13 (left: 3, 13)
# 3. 13 * 3 = 39 (left: 39)
# 4. 39 / 3 = 13 (left: 13)
# 5. 13 + 2 = 15 (left: 15)
# 6. 15 - 9 = 6 (left: 6)
# 7. 6 * 8 = 24 (left: 24)
#
# And the answer is:
#
# (9 + 6) * ((3 - 2) * (13 / 3) + (15 - 9)) = 24
# output generated
# ["A fun challenge!\n\nLet's go through the steps:\n\n1. 9 + 6 = 15 (left: 2, 3, 15)\n2. 15 - 2 = 13 (left: 3, 13)\n3. 13 * 3 = 39 (left: 39)\n4. 39 / 3 = 13 (left: 13)\n5. 13 + 2 = 15 (left: 15)\n6. 15 - 9 = 6 (left: 6)\n7. 6 * 8 = 24 (left: 24)\n\nAnd the answer is:\n\n(9 + 6) * ((3 - 2) * (13 / 3) + (15 - 9)) = 24"]

# %%
ys, infos = naive_solve(args, task, 908)
print(ys)
# Out:
# functools.partial(<function gpt at 0x000001EDCA027B00>, model='llama3', temperature=0.7)
# output generating get_samples
# Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.
# Input: 4 4 6 8
# Steps:
# 4 + 8 = 12 (left: 4 6 12)
# 6 - 4 = 2 (left: 2 12)
# 2 * 12 = 24 (left: 24)
# Answer: (6 - 4) * (4 + 8) = 24
# Input: 2 9 10 12
# Steps:
# 12 * 2 = 24 (left: 9 10 24)
# 10 - 9 = 1 (left: 1 24)
# 24 * 1 = 24 (left: 24)
# Answer: (12 * 2) * (10 - 9) = 24
# Input: 4 9 10 13
# Steps:
# 13 - 10 = 3 (left: 3 4 9)
# 9 - 3 = 6 (left: 4 6)
# 4 * 6 = 24 (left: 24)
# Answer: 4 * (9 - (13 - 10)) = 24
# Input: 1 4 8 8
# Steps:
# 8 / 4 = 2 (left: 1 2 8)
# 1 + 2 = 3 (left: 3 8)
# 3 * 8 = 24 (left: 24)
# Answer: (1 + 8 / 4) * 8 = 24
# Input: 5 5 5 9
# Steps:
# 5 + 5 = 10 (left: 5 9 10)
# 10 + 5 = 15 (left: 9 15)
# 15 + 9 = 24 (left: 24)
# Answer: ((5 + 5) + 5) + 9 = 24
# Input: 1 3 5 9
#
# 1
# 1 [{'role': 'user', 'content': 'Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.\nInput: 4 4 6 8\nSteps:\n4 + 8 = 12 (left: 4 6 12)\n6 - 4 = 2 (left: 2 12)\n2 * 12 = 24 (left: 24)\nAnswer: (6 - 4) * (4 + 8) = 24\nInput: 2 9 10 12\nSteps:\n12 * 2 = 24 (left: 9 10 24)\n10 - 9 = 1 (left: 1 24)\n24 * 1 = 24 (left: 24)\nAnswer: (12 * 2) * (10 - 9) = 24\nInput: 4 9 10 13\nSteps:\n13 - 10 = 3 (left: 3 4 9)\n9 - 3 = 6 (left: 4 6)\n4 * 6 = 24 (left: 24)\nAnswer: 4 * (9 - (13 - 10)) = 24\nInput: 1 4 8 8\nSteps:\n8 / 4 = 2 (left: 1 2 8)\n1 + 2 = 3 (left: 3 8)\n3 * 8 = 24 (left: 24)\nAnswer: (1 + 8 / 4) * 8 = 24\nInput: 5 5 5 9\nSteps:\n5 + 5 = 10 (left: 5 9 10)\n10 + 5 = 15 (left: 9 15)\n15 + 9 = 24 (left: 24)\nAnswer: ((5 + 5) + 5) + 9 = 24\nInput: 1 3 5 9\n'}]
# A fun problem!
#
# Let's try to find the solution:
#
# Steps:
# 9 - 5 = 4 (left: 1 3 4)
# 3 + 1 = 4 (left: 4)
# 4 * 4 = 16 (left: 16)
# 16 + 8 = 24 (left: 24)
#
# Answer: ((9 - 5) + 1) * 3 = 24
# output generated
# ["A fun problem!\n\nLet's try to find the solution:\n\nSteps:\n9 - 5 = 4 (left: 1 3 4)\n3 + 1 = 4 (left: 4)\n4 * 4 = 16 (left: 16)\n16 + 8 = 24 (left: 24)\n\nAnswer: ((9 - 5) + 1) * 3 = 24"]

# %%
ys, infos = naive_solve(args, task, 909)
print(ys)
# Out:
# functools.partial(<function gpt at 0x000001EDCA027B00>, model='llama3', temperature=0.7)
# output generating get_samples
# Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.
# Input: 4 4 6 8
# Steps:
# 4 + 8 = 12 (left: 4 6 12)
# 6 - 4 = 2 (left: 2 12)
# 2 * 12 = 24 (left: 24)
# Answer: (6 - 4) * (4 + 8) = 24
# Input: 2 9 10 12
# Steps:
# 12 * 2 = 24 (left: 9 10 24)
# 10 - 9 = 1 (left: 1 24)
# 24 * 1 = 24 (left: 24)
# Answer: (12 * 2) * (10 - 9) = 24
# Input: 4 9 10 13
# Steps:
# 13 - 10 = 3 (left: 3 4 9)
# 9 - 3 = 6 (left: 4 6)
# 4 * 6 = 24 (left: 24)
# Answer: 4 * (9 - (13 - 10)) = 24
# Input: 1 4 8 8
# Steps:
# 8 / 4 = 2 (left: 1 2 8)
# 1 + 2 = 3 (left: 3 8)
# 3 * 8 = 24 (left: 24)
# Answer: (1 + 8 / 4) * 8 = 24
# Input: 5 5 5 9
# Steps:
# 5 + 5 = 10 (left: 5 9 10)
# 10 + 5 = 15 (left: 9 15)
# 15 + 9 = 24 (left: 24)
# Answer: ((5 + 5) + 5) + 9 = 24
# Input: 3 3 7 12
#
# 1
# 1 [{'role': 'user', 'content': 'Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.\nInput: 4 4 6 8\nSteps:\n4 + 8 = 12 (left: 4 6 12)\n6 - 4 = 2 (left: 2 12)\n2 * 12 = 24 (left: 24)\nAnswer: (6 - 4) * (4 + 8) = 24\nInput: 2 9 10 12\nSteps:\n12 * 2 = 24 (left: 9 10 24)\n10 - 9 = 1 (left: 1 24)\n24 * 1 = 24 (left: 24)\nAnswer: (12 * 2) * (10 - 9) = 24\nInput: 4 9 10 13\nSteps:\n13 - 10 = 3 (left: 3 4 9)\n9 - 3 = 6 (left: 4 6)\n4 * 6 = 24 (left: 24)\nAnswer: 4 * (9 - (13 - 10)) = 24\nInput: 1 4 8 8\nSteps:\n8 / 4 = 2 (left: 1 2 8)\n1 + 2 = 3 (left: 3 8)\n3 * 8 = 24 (left: 24)\nAnswer: (1 + 8 / 4) * 8 = 24\nInput: 5 5 5 9\nSteps:\n5 + 5 = 10 (left: 5 9 10)\n10 + 5 = 15 (left: 9 15)\n15 + 9 = 24 (left: 24)\nAnswer: ((5 + 5) + 5) + 9 = 24\nInput: 3 3 7 12\n'}]
# Let's go through the steps to obtain 24:
#
# 1. 12 + 3 = 15 (left: 3 7 15)
# 2. 7 - 3 = 4 (left: 4 15)
# 3. 15 * 4 = 60 (not what we want, so let's backtrack)
# 4. 12 / 3 = 4 (left: 3 7 4)
# 5. 4 + 3 = 7 (left: 7 7)
# 6. 7 + 7 = 14 (not what we want, so let's backtrack again)
# 7. 3 * 7 = 21 (not what we want, so let's try another combination)
# 8. 12 - 3 = 9 (left: 3 9 7)
# 9. 9 + 7 = 16 (not what we want, so let's backtrack again)
# 10. 7 * 3 = 21 (not what we want, so let's try another combination)
# 11. 12 - 7 = 5 (left: 5 3 3)
# 12. 3 + 3 = 6 (left: 5 6)
# 13. 5 * 6 = 30 (not what we want, so let's backtrack again)
# 14. 3 / 3 = 1 (left: 5 1)
# 15. 5 - 1 = 4 (left: 4)
# 16. 4 * 12 = 48 (not what we want, so let's try another combination)
# 17. 7 + 5 = 12 (left: 2 12)
# 18. 12 / 2 = 6 (left: 6)
# 19. 6 * 4 = 24 (finally!)
#
# So, the correct steps to obtain 24 are:
#
# (3 - 7) * ((12 - 3) + 3)
#
# Note that this solution involves using parentheses to clarify the order of operations.
# output generated
# ["Let's go through the steps to obtain 24:\n\n1. 12 + 3 = 15 (left: 3 7 15)\n2. 7 - 3 = 4 (left: 4 15)\n3. 15 * 4 = 60 (not what we want, so let's backtrack)\n4. 12 / 3 = 4 (left: 3 7 4)\n5. 4 + 3 = 7 (left: 7 7)\n6. 7 + 7 = 14 (not what we want, so let's backtrack again)\n7. 3 * 7 = 21 (not what we want, so let's try another combination)\n8. 12 - 3 = 9 (left: 3 9 7)\n9. 9 + 7 = 16 (not what we want, so let's backtrack again)\n10. 7 * 3 = 21 (not what we want, so let's try another combination)\n11. 12 - 7 = 5 (left: 5 3 3)\n12. 3 + 3 = 6 (left: 5 6)\n13. 5 * 6 = 30 (not what we want, so let's backtrack again)\n14. 3 / 3 = 1 (left: 5 1)\n15. 5 - 1 = 4 (left: 4)\n16. 4 * 12 = 48 (not what we want, so let's try another combination)\n17. 7 + 5 = 12 (left: 2 12)\n18. 12 / 2 = 6 (left: 6)\n19. 6 * 4 = 24 (finally!)\n\nSo, the correct steps to obtain 24 are:\n\n(3 - 7) * ((12 - 3) + 3)\n\nNote that this solution involves using parentheses to clarify the order of operations."]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
